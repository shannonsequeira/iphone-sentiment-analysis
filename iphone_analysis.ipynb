# %% [markdown]
# # iPhone Insights: Decoding Consumer Sentiments Across Apple's Latest Models

# %% [markdown]
# ## 1) Data Preprocessing for iPhone Review Analysis

# %%
import pandas as pd
import os

os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  'Apple iPhone 13.csv',
#  'Apple iPhone 14 Pro Max.csv',
#  'Apple iPhone 14.csv',
#  'Apple iPhone 15 Pro Max.csv',
#  'Apple iPhone 15 Pro.csv',
#  'Apple iPhone 15.csv',
#  'cleaned_iphone_reviews.csv',
#  'distribution.png',
#  'iphone_analysis.ipynb',
#  'iphone_reviews_sentiment_analysis.csv',
#  'iPhone_sentiment_analysis.ows',
#  'linear projection.png',
#  'preprocess_text_wordcloud.png',
#  'radviz.png',
#  'scatterplot.png',
#  'sentiment_analysis_results.csv',
#  'sentiment_analysis_results.csv.metadata',
#  'wordcloud.png']

# %%
df1 = pd.read_csv('Apple iPhone 13.csv')
df2 = pd.read_csv('Apple iPhone 14.csv')
df3 = pd.read_csv('Apple iPhone 14 Pro Max.csv')
df4 = pd.read_csv('Apple iPhone 15.csv')
df5 = pd.read_csv('Apple iPhone 15 Pro.csv')
df6 = pd.read_csv('Apple iPhone 15 Pro Max.csv')

# %%
df1.head()
# Out:
#            Name              Rating                                   Date  \
# 0   Jnan Shetty  5.0 out of 5 stars  Reviewed in India on 30 December 2023
# 1  Pankaj Kumar  5.0 out of 5 stars  Reviewed in India on 24 February 2024
# 2         Adeeb  4.0 out of 5 stars    Reviewed in India on 19 August 2024
# 3         manoj  5.0 out of 5 stars      Reviewed in India on 24 July 2024
# 4       loading  5.0 out of 5 stars      Reviewed in India on 22 June 2024
#
#               Type                        Details  \
# 0  Apple iPhone 13       Colour: BlueSize: 128 GB
# 1  Apple iPhone 13  Colour: StarlightSize: 128 GB
# 2  Apple iPhone 13       Colour: PinkSize: 128 GB
# 3  Apple iPhone 13       Colour: BlueSize: 128 GB
# 4  Apple iPhone 13       Colour: PinkSize: 128 GB
#
#                                                Title  \
# 0                 Using after 3 months honest review
# 1  Redefining Excellence: A Review of the iPhone ...
# ...

# %%
df2.head()
# Out:
#              Name              Rating                                 Date  \
# 0     meemansa s.  5.0 out of 5 stars    Reviewed in India on 19 July 2024
# 1        Vijay A.  5.0 out of 5 stars    Reviewed in India on 16 July 2024
# 2        Krishanu  4.0 out of 5 stars  Reviewed in India on 10 August 2024
# 3  Gajendra Singh  5.0 out of 5 stars    Reviewed in India on 12 June 2024
# 4         Crystal  5.0 out of 5 stars    Reviewed in India on 21 July 2024
#
#               Type                     Details                    Title  \
# 0  Apple iPhone 14  Colour: PurpleSize: 128 GB         BEST PURCHASE!!!
# 1  Apple iPhone 14    Colour: BlueSize: 128 GB              Vijay Kumar
# 2  Apple iPhone 14                         NaN             Nice product
# 3  Apple iPhone 14  Colour: PurpleSize: 128 GB  Nothing beats an iPhone
# 4  Apple iPhone 14    Colour: BlueSize: 128 GB              Great phone
#
#                                               Review
# ...

# %%
df3.head()
# Out:
#              Name              Rating                                    Date  \
# 0  Peeyoosh Kumar  5.0 out of 5 stars       Reviewed in India on 28 July 2023
# 1            Benu  5.0 out of 5 stars        Reviewed in India on 25 May 2023
# 2        Rohit D.  5.0 out of 5 stars  Reviewed in India on 21 September 2022
# 3     Harsh Singh  5.0 out of 5 stars   Reviewed in India on 25 November 2022
# 4       balyogesh  4.0 out of 5 stars   Reviewed in India on 16 November 2023
#
#                       Type  Details  \
# 0  Apple iPhone 14 Pro Max      NaN
# 1  Apple iPhone 14 Pro Max      NaN
# 2  Apple iPhone 14 Pro Max      NaN
# 3  Apple iPhone 14 Pro Max      NaN
# 4  Apple iPhone 14 Pro Max      NaN
#
#                                                Title  \
# 0    The iPhone 14 Pro Max: An Epitome of Excellence
# 1  The Apple Pro Max 14: A Powerful Beast That De...
# 2                        Welcome to "Dynamic Island"
# 3                                   Best iPhone yet.
# ...

# %%
df4.head()
# Out:
#                     Name              Rating  \
# 0         Sandy Cariappa  5.0 out of 5 stars
# 1         Rohan narvekar  5.0 out of 5 stars
# 2  HINDUSTAN ELECTRICALS  5.0 out of 5 stars
# 3                  stuti  4.0 out of 5 stars
# 4                   Shiv  5.0 out of 5 stars
#
#                                   Date             Type  \
# 0  Reviewed in India on 7 October 2023  Apple iPhone 15
# 1    Reviewed in India on 24 July 2024  Apple iPhone 15
# 2  Reviewed in India on 6 October 2023  Apple iPhone 15
# 3    Reviewed in India on 31 July 2024  Apple iPhone 15
# 4  Reviewed in India on 14 August 2024  Apple iPhone 15
#
#                      Details  \
# 0   Colour: BlueSize: 128 GB
# 1   Colour: BlueSize: 128 GB
# 2  Colour: BlackSize: 128 GB
# 3   Colour: BlueSize: 128 GB
# 4  Colour: BlackSize: 128 GB
#
#                                                Title  \
# 0                             iPhone XR to iPhone 15
# 1  Iphone from Apple as usual top in quality and ...
# ...

# %%
df5.head()
# Out:
#                Name              Rating  \
# 0  Arghya Mukherjee  5.0 out of 5 stars
# 1     Neeraj Thakur  5.0 out of 5 stars
# 2     Vineet Sharma  4.0 out of 5 stars
# 3    satwik mohanty  5.0 out of 5 stars
# 4     Radhakrishnan  1.0 out of 5 stars
#
#                                     Date                 Type  \
# 0    Reviewed in India on 15 August 2024  Apple iPhone 15 Pro
# 1      Reviewed in India on 30 July 2024  Apple iPhone 15 Pro
# 2     Reviewed in India on 15 April 2024  Apple iPhone 15 Pro
# 3       Reviewed in India on 31 May 2024  Apple iPhone 15 Pro
# 4  Reviewed in India on 18 February 2024  Apple iPhone 15 Pro
#
#                               Details  \
# 0  Colour: Black TitaniumSize: 256 GB
# 1  Colour: Black TitaniumSize: 128 GB
# 2  Colour: Black TitaniumSize: 256 GB
# 3   Colour: Blue TitaniumSize: 128 GB
# 4   Colour: Blue TitaniumSize: 256 GB
#
#                                                Title  \
# ...

# %%
df6.head()
# Out:
#                  Name              Rating  \
# 0  shobhit srivastava  5.0 out of 5 stars
# 1     vikash bhardwaj  5.0 out of 5 stars
# 2         Jay Prakash  5.0 out of 5 stars
# 3         vikas batra  5.0 out of 5 stars
# 4          Slim Kells  1.0 out of 5 stars
#
#                                     Date                     Type  \
# 0    Reviewed in India on 31 August 2024  Apple iPhone 15 Pro Max
# 1       Reviewed in India on 15 May 2024  Apple iPhone 15 Pro Max
# 2  Reviewed in India on 1 September 2024  Apple iPhone 15 Pro Max
# 3     Reviewed in India on 9 August 2024  Apple iPhone 15 Pro Max
# 4      Reviewed in India on 15 June 2024  Apple iPhone 15 Pro Max
#
#                               Details                              Title  \
# 0  Colour: White TitaniumSize: 256 GB            Smooth and Professional
# 1  Colour: Black TitaniumSize: 256 GB                       phone camera
# 2   Colour: Blue TitaniumSize: 256 GB                               Nice
# ...

# %%
# Combine all DataFrames into one
all_data = pd.concat([df1, df2, df3, df4, df5, df6], ignore_index=True)

# %%
all_data.sample(10)
# Out:
#                 Name              Rating  \
# 333  Amazon Customer  5.0 out of 5 stars
# 229        Chaitanya  3.0 out of 5 stars
# 228   AMARTYA SARKAR  5.0 out of 5 stars
# 466     Sai Abhi Ram  1.0 out of 5 stars
# 417                K  4.0 out of 5 stars
# 356            Nirin  4.0 out of 5 stars
# 320    Rajeev Sharma  5.0 out of 5 stars
# 425  Amazon Customer  5.0 out of 5 stars
# 334       Prakash V.  5.0 out of 5 stars
# 391           Bushan  5.0 out of 5 stars
#
#                                        Date                     Type  \
# 333       Reviewed in India on 24 July 2024          Apple iPhone 15
# 229      Reviewed in India on 30 April 2023  Apple iPhone 14 Pro Max
# 228  Reviewed in India on 22 September 2022  Apple iPhone 14 Pro Max
# 466       Reviewed in India on 15 June 2024      Apple iPhone 15 Pro
# 417    Reviewed in India on 11 January 2024      Apple iPhone 15 Pro
# 356       Reviewed in India on 6 April 2024          Apple iPhone 15
# ...

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     600 non-null    object
#  1   Rating   600 non-null    object
#  2   Date     600 non-null    object
#  3   Type     600 non-null    object
#  4   Details  449 non-null    object
#  5   Title    600 non-null    object
#  6   Review   600 non-null    object
# dtypes: object(7)
# memory usage: 32.9+ KB

# %%
all_data.describe()
# Out:
#                Name              Rating                                 Date  \
# count           600                 600                                  600
# unique          551                   5                                  328
# top     Placeholder  5.0 out of 5 stars  Reviewed in India on 10 August 2024
# freq             19                 388                                    7
#
#                    Type                   Details Title Review
# count               600                       449   600    600
# unique                6                        31   503    566
# top     Apple iPhone 13  Colour: BlueSize: 128 GB  Good   Good
# freq                100                        69    31      9

# %%
all_data.shape
# Out:
# (600, 7)

# %%
# Returns a DataFrame with True where values are missing
all_data.isnull()
# Out:
#       Name  Rating   Date   Type  Details  Title  Review
# 0    False   False  False  False    False  False   False
# 1    False   False  False  False    False  False   False
# 2    False   False  False  False    False  False   False
# 3    False   False  False  False    False  False   False
# 4    False   False  False  False    False  False   False
# ..     ...     ...    ...    ...      ...    ...     ...
# 595  False   False  False  False    False  False   False
# 596  False   False  False  False    False  False   False
# 597  False   False  False  False    False  False   False
# 598  False   False  False  False    False  False   False
# 599  False   False  False  False    False  False   False
#
# [600 rows x 7 columns]

# %%
# Sum of missing values in each column
all_data.isnull().sum()
# Out:
# Name         0
# Rating       0
# Date         0
# Type         0
# Details    151
# Title        0
# Review       0
# dtype: int64

# %%
# Handle NaN values by filling them with a placeholder
all_data['Details'] = all_data['Details'].fillna('No Details')

# %%
# Sum of missing values in each column
all_data.isnull().sum()
# Out:
# Name       0
# Rating     0
# Date       0
# Type       0
# Details    0
# Title      0
# Review     0
# dtype: int64

# %%
all_data.describe()
# Out:
#                Name              Rating                                 Date  \
# count           600                 600                                  600
# unique          551                   5                                  328
# top     Placeholder  5.0 out of 5 stars  Reviewed in India on 10 August 2024
# freq             19                 388                                    7
#
#                    Type     Details Title Review
# count               600         600   600    600
# unique                6          32   503    566
# top     Apple iPhone 13  No Details  Good   Good
# freq                100         151    31      9

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     600 non-null    object
#  1   Rating   600 non-null    object
#  2   Date     600 non-null    object
#  3   Type     600 non-null    object
#  4   Details  600 non-null    object
#  5   Title    600 non-null    object
#  6   Review   600 non-null    object
# dtypes: object(7)
# memory usage: 32.9+ KB

# %%
all_data.sample(5)
# Out:
#                                                   Name              Rating  \
# 211                                           Jewel B.  5.0 out of 5 stars
# 494                                        Placeholder  1.0 out of 5 stars
# 173                                   Return to refund  5.0 out of 5 stars
# 591  Not good product nothing has changed from iPho...  1.0 out of 5 stars
# 247                Its a fake product dnt buy any more  5.0 out of 5 stars
#
#                                     Date                     Type  \
# 211   Reviewed in India on 6 August 2023  Apple iPhone 14 Pro Max
# 494  Reviewed in India on 3 October 2023      Apple iPhone 15 Pro
# 173    Reviewed in India on 6 April 2024          Apple iPhone 14
# 591    Reviewed in India on 15 June 2024  Apple iPhone 15 Pro Max
# 247  Reviewed in India on 6 October 2023  Apple iPhone 14 Pro Max
#
#                                 Details                     Title  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# Combine all reviews into a single string
text = ' '.join(all_data['Review'])

# Generate a word cloud
plt.figure(figsize=(12, 8))
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Reviews')
plt.show()

# %%
# Calculate the length of each review
all_data['Review_Length'] = all_data['Review'].apply(len)

# Plot the distribution of review lengths
plt.figure(figsize=(10, 5))
sns.histplot(all_data['Review_Length'], bins=30, color='teal', kde=True)
plt.title('Distribution of Review Lengths')
plt.xlabel('Review Length (characters)')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot the count of reviews by type
plt.figure(figsize=(10, 6))
sns.countplot(x='Type', data=all_data, hue='Type', palette='coolwarm')
plt.title('Count of Reviews by Type')
plt.xlabel('Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Save cleaned combined DataFrame
all_data.to_csv('cleaned_iphone_reviews.csv', index=False)

# %% [markdown]
# ## 2) Review and Inspect the Sentiment Analysis Results

# %%
# Load the sentiment analysis results
sentiment_df = pd.read_csv('sentiment_analysis_results.csv')

# %%
sentiment_df.sample(10)
# Out:
#                   Name                                   Date  \
# 400          Mohd Amir       Reviewed in India on 18 May 2024
# 448       sourav misra      Reviewed in India on 23 July 2024
# 596  Arun pratap singh   Reviewed in India on 13 January 2024
# 260    Bhavani Shankar      Reviewed in India on 30 July 2023
# 172               Karn       Reviewed in India on 10 May 2023
# 431       Wasil Akhtar  Reviewed in India on 27 December 2023
# 427    Amazon Customer   Reviewed in India on 7 February 2024
# 263   Aditya Choudhary     Reviewed in India on 2 August 2023
# 356   Debabrata Sarkar     Reviewed in India on 15 April 2024
# 381    aswathy sathyan     Reviewed in India on 10 March 2024
#
#                                                  Title  \
# 400                              Excellent performance
# 448                        The best phone one can have
# 596                              I phone15 pro maximum
# 260                                        Outstanding
# ...

# %%
sentiment_df['compound'] = pd.to_numeric(sentiment_df['compound'], errors='coerce')
sentiment_df['positive'] = pd.to_numeric(sentiment_df['positive'], errors='coerce')
sentiment_df['neutral'] = pd.to_numeric(sentiment_df['neutral'], errors='coerce')
sentiment_df['negative'] = pd.to_numeric(sentiment_df['negative'], errors='coerce')

# %%
sentiment_df.sample(10)
# Out:
#                 Name                                   Date  \
# 272            Rahul      Reviewed in India on 9 March 2023
# 302   Sandy Cariappa    Reviewed in India on 7 October 2023
# 349   subhadip manna   Reviewed in India on 12 October 2023
# 224           Kalyan     Reviewed in India on 8 August 2023
# 587         Carelien     Reviewed in India on 7 August 2024
# 114          Gowtham       Reviewed in India on 30 May 2024
# 210  Amazon Customer    Reviewed in India on 10 August 2024
# 119      Chetana K K      Reviewed in India on 19 June 2024
# 431     Wasil Akhtar  Reviewed in India on 27 December 2023
# 577            tisha       Reviewed in India on 12 May 2024
#
#                               Title  \
# 272                        Perfect.
# 302          iPhone XR to iPhone 15
# 349  It's about the great iPhone 15
# 224                          Camera
# 587                         SCAM!!!
# 114     Performance and ease of use
# 210       Heating or charging issue
# ...

# %%
sentiment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602 entries, 0 to 601
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      602 non-null    object
#  1   Date      602 non-null    object
#  2   Title     602 non-null    object
#  3   Review    601 non-null    object
#  4   Rating    601 non-null    object
#  5   Type      601 non-null    object
#  6   Details   601 non-null    object
#  7   positive  600 non-null    float64
#  8   negative  600 non-null    float64
#  9   neutral   600 non-null    float64
#  10  compound  600 non-null    float64
# dtypes: float64(4), object(7)
# memory usage: 51.9+ KB

# %%
sentiment_df.describe()
# Out:
#          positive    negative     neutral    compound
# count  600.000000  600.000000  600.000000  600.000000
# mean     0.310165    0.038420    0.644753    0.433373
# std      0.290654    0.081789    0.277721    0.459277
# min      0.000000    0.000000    0.000000   -0.947400
# 25%      0.095750    0.000000    0.487250    0.000000
# 50%      0.224500    0.000000    0.720500    0.513950
# 75%      0.487000    0.047000    0.833000    0.803350
# max      1.000000    0.556000    1.000000    0.999900

# %% [markdown]
# ## 3) Thematic Analysis

# %% [markdown]
# ### Extracting key themes

# %%
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
# Replace NaN values with an empty string or a placeholder
sentiment_df['Review'] = sentiment_df['Review'].fillna('No Review')
sentiment_df['Details'] = sentiment_df['Details'].fillna('No Details')

# %%
# Tokenization and Stopwords Removal
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(sentiment_df['Review'])

# %%
sentiment_df.sample(5)
# Out:
#                 Name                                  Date  \
# 436  Amazon Customer  Reviewed in India on 8 November 2023
# 537     Sharf Unnisa    Reviewed in India on 7 August 2024
# 328    kedar tondare     Reviewed in India on 31 July 2024
# 19    Rohit Pahadiya   Reviewed in India on 13 August 2024
# 27       ayush verma   Reviewed in India on 30 August 2024
#
#                                                  Title  \
# 436  Great phone but not value for money especially...
# 537                                               Fake
# 328                                   Abb hum kya bole
# 19                                             Amazing
# 27                             Not as good as expected
#
#                                                 Review              Rating  \
# 436  Great phone but not value for money especially...  5.0 out of 5 stars
# 537         Fake product , paid 1,89,400/-got 0 refund  1.0 out of 5 stars
# ...

# %%
# Topic Modeling
lda = LatentDirichletAllocation(n_components=5, random_state=0)
lda.fit(X)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=0)

# %%
# Display topics
for index, topic in enumerate(lda.components_):
    print(f'Topic #{index}:')
    print([vectorizer.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
# Out:
# Topic #0:
# ['samsung', 'phone', 'better', 'camera', 'battery', 'people', 'helpful', 'android', '10', 'iphone']
# Topic #1:
# ['features', 'use', 'battery', 'camera', 'performance', 'display', 'apple', '13', 'phone', 'iphone']
# Topic #2:
# ['display', 'good', 'battery', 'apple', 'max', 'camera', '14', 'phone', 'pro', 'iphone']
# Topic #3:
# ['14', 'amazon', 'pro', 'good', 'great', 'like', 'product', 'iphone', 'apple', 'phone']
# Topic #4:
# ['iphone', 'quality', 'device', 'money', 'nice', 'phone', 'best', 'camera', 'product', 'good']

# %%
# Manual tagging
def categorize_review(review_text):
    # Define themes and associated keywords relevant to iPhone reviews
    themes = {
        'Design': ['design', 'look', 'style', 'appearance', 'build quality'],
        'Performance': ['fast', 'slow', 'speed', 'performance', 'lag'],
        'Camera': ['camera', 'photography', 'photo', 'video quality','image'],
        'Battery Life': ['battery', 'battery life', 'charging', 'battery performance'],
        'Display': ['screen', 'display', 'resolution', 'brightness'],
        'Software': ['iOS', 'software', 'updates', 'features'],
        'Price': ['price', 'cost', 'expensive', 'affordable','value for money'],
        'Durability': ['durable', 'fragile', 'sturdy'],
        'Feel': ['touch', 'sensitivity', 'love','like','happy','great','best','awesome','super','superb','premium','amazing','good','nice'],
        'Audio': ['sound','music','song'],
    }
    
    # Convert review text to lowercase
    review_text = review_text.lower()
    
    # Initialize the theme
    theme = 'Other'
    
    # Categorize based on keywords
    for key, keywords in themes.items():
        if any(keyword in review_text for keyword in keywords):
            theme = key
            break
    
    return theme

# %%
# Apply the categorize_review function to the 'Review' column
sentiment_df['Theme'] = sentiment_df['Review'].apply(lambda x: categorize_review(x) if pd.notna(x) else 'Other')

# %%
# Handle NaN values by filling them with a placeholder or dropping them
sentiment_df['Review'] = sentiment_df['Review'].fillna('No Review')

# %%
sentiment_df.sample(10)
# Out:
#                                                   Name  \
# 466                                  Gourav bhadouriya
# 333                                             Haneef
# 41                                         Arjun saini
# 511                                       KP Chaudhary
# 261                                        Rahul ahuja
# 37                                         Placeholder
# 462                                        Placeholder
# 12                           Siddhardha Sagar. Rekhala
# 4                                                Adeeb
# 501  An absolute delight to have this phone. This i...
#
#                                       Date  \
# 466       Reviewed in India on 6 June 2024
# 333      Reviewed in India on 31 July 2024
# 41     Reviewed in India on 26 August 2024
# 511      Reviewed in India on 15 June 2024
# 261   Reviewed in India on 26 October 2022
# 37     Reviewed in India on 16 August 2024
# 462   Reviewed in India on 11 October 2023
# ...

# %%
sentiment_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602 entries, 0 to 601
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      602 non-null    object
#  1   Date      602 non-null    object
#  2   Title     602 non-null    object
#  3   Review    602 non-null    object
#  4   Rating    601 non-null    object
#  5   Type      601 non-null    object
#  6   Details   602 non-null    object
#  7   positive  600 non-null    float64
#  8   negative  600 non-null    float64
#  9   neutral   600 non-null    float64
#  10  compound  600 non-null    float64
#  11  Theme     602 non-null    object
# dtypes: float64(4), object(8)
# memory usage: 56.6+ KB

# %%
# Aggregate sentiment scores by theme
theme_sentiment = sentiment_df.groupby('Theme')['compound'].mean().reset_index()

# Prepare data for donut chart
themes = theme_sentiment['Theme']
sentiments = theme_sentiment['compound']

# Create a donut chart
plt.figure(figsize=(5, 5))
plt.pie(sentiments, labels=themes, autopct='%1.1f%%', startangle=140, colors=sns.color_palette())

# Draw a circle in the center to make it a donut
centre_circle = plt.Circle((0, 0), 0.5, color='white', fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Average Sentiment Score by Theme')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
# Aggregate sentiment scores by theme
theme_sentiment = sentiment_df.groupby('Theme')['compound'].mean().reset_index()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Theme', y='compound', data=theme_sentiment)
plt.xticks(rotation=45)
plt.title('Average Sentiment Score by Theme')
plt.show()

# %%
# Convert 'Rating' to a numeric type (if ratings are like '4.0 out of 5 stars')
sentiment_df['Numeric_Rating'] = sentiment_df['Rating'].str.extract(r'(\d+\.\d+)').astype(float)

# %%
sentiment_df.sample(10)
# Out:
#                 Name                                   Date  \
# 53    Shreem Dwivedi     Reviewed in India on 9 August 2024
# 142      Placeholder      Reviewed in India on 6 April 2024
# 32             Ketan    Reviewed in India on 31 August 2024
# 288           Vishal       Reviewed in India on 18 May 2023
# 273       Rajive Dey      Reviewed in India on 28 June 2023
# 487              Raj   Reviewed in India on 25 October 2023
# 159  Amazon Customer      Reviewed in India on 4 April 2024
# 526           vamshi  Reviewed in India on 15 December 2023
# 341       sonu kumar      Reviewed in India on 12 July 2024
# 564     Chirag Patel    Reviewed in India on 13 August 2024
#
#                     Title                                             Review  \
# 53                 Sparky                                  Trend setter ❤️‍🔥
# 142  Review after 1 years  1) Display - 4/52) durability - 3/53) Battery ...
# ...

# %%
plt.figure(figsize=(8, 6))
sns.histplot(sentiment_df['Numeric_Rating'], bins=5, kde=True)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot distribution of sentiments
plt.figure(figsize=(10, 6))
sns.histplot(sentiment_df[['positive', 'negative', 'neutral']], kde=True)
plt.title('Distribution of Sentiments (Positive, Negative, Neutral)')
plt.xlabel('Sentiment Scores')
plt.ylabel('Frequency')
plt.show()

# %%
# Sentiment vs Rating (Compound Sentiment)
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Numeric_Rating', y='compound', hue='Type', data=sentiment_df)
plt.title('Rating vs Compound Sentiment Score')
plt.xlabel('Rating')
plt.ylabel('Compound Sentiment')
plt.show()

# %%
# Boxplot to show sentiment (compound) for each theme
plt.figure(figsize=(10, 6))
sns.boxplot(x='Theme', y='compound', data=sentiment_df)
plt.title('Compound Sentiment by Theme')
plt.xlabel('Theme')
plt.ylabel('Compound Sentiment')
plt.xticks(rotation=45)
plt.show()

# %%
# Aggregate sentiment proportions
sentiment_counts = sentiment_df[['positive', 'negative', 'neutral']].sum()

# Plot donut chart
plt.figure(figsize=(5,5))
plt.pie(sentiment_counts, 
        labels=['Positive', 'Negative', 'Neutral'], 
        autopct='%1.1f%%', 
        colors=['lightgreen', 'red', 'grey'],
        wedgeprops=dict(width=0.4))  # Adjust width to create the donut effect
plt.title('Sentiment Distribution')
plt.show()

# %%
# Categorizing sentiment into 'positive', 'neutral', 'negative' based on compound score
sentiment_df['Sentiment_Category'] = sentiment_df['compound'].apply(lambda x: 'positive' if x > 0 else ('negative' if x < 0 else 'neutral'))

# Count the number of reviews in each sentiment category
sentiment_counts = sentiment_df['Sentiment_Category'].value_counts()

# Plot sentiment categories
plt.figure(figsize=(8, 6))
sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values)
plt.title('Sentiment Categories Count')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(sentiment_df['compound'], bins=20, color='pink', edgecolor='black')
plt.xlabel('Compound Score')
plt.ylabel('Frequency')
plt.title('Histogram of Compound Sentiment Scores')
plt.show()

# %%
import matplotlib.pyplot as plt

# Scatter plot for sentiment scores
plt.figure(figsize=(10, 6))
plt.scatter(sentiment_df['positive'], sentiment_df['negative'], c=sentiment_df['compound'], cmap='viridis', alpha=0.7)
plt.colorbar(label='Compound Score')
plt.xlabel('Positive Score')
plt.ylabel('Negative Score')
plt.title('Sentiment Analysis Scatter Plot')
plt.show()

# %%
from wordcloud import WordCloud

# Combine all reviews into a single text
text = ' '.join(review for review in sentiment_df['Review'])

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Display word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of iPhone Reviews')
plt.show()

# %%
# Calculate correlation matrix
corr = sentiment_df[['positive', 'negative', 'neutral', 'compound']].corr()

# Create a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, vmin=-1, vmax=1, center=0, fmt='.2f')
plt.title('Correlation Heatmap of Sentiment Scores')
plt.show()
